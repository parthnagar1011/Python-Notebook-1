# %% [markdown]
# This unit include topic's like -
#
#
# *  List
# *  Tuples
# *  Sets
# *  Dictionaries

# %% [markdown]
# ## List
#
# It is a collection of item in a particular oredr. We can make list using [].
# In list items are ordered, duplicate, changable.
# Order means items have defined order that can't change.
# changeable means we can add items afte creating the list.

# %%
# creating a list
color = ['red', 'green', 'blue', 'yellow']
color
# Out:
# ['red', 'green', 'blue', 'yellow']

# %%
# we can access list usinf indexing
color[1]
# Out:
# 'green'

# %%
# print list using loop
for c in color:
  print(c)
# Out:
# red
# green
# blue
# yellow

# %%
# slicing
color[1:3]
# Out:
# ['green', 'blue']

# %%
# Replacin element using slicing'
color[1:2] = ['orange']
color
# Out:
# ['red', 'orange', 'blue', 'yellow']

# %% [markdown]
# ### Modify List
#
#
# 1.   append() - Adds item at end of list.
# 2.   insert() - This method insert item at given index. User has to specify index and item to ber inserted.
# 3.   extend() - This method extends the entire list by adding another list.
# 4.   pop() - Removes the last item from the list.
# 5.   remove() - This method removes the specific item from list by specifying the list.
# 6.   del - It is not any method, it is a keyword which delete specific item or full list.
# 7.   clear() - Delete the entitre list and print empty list.

# %%
rainbow = ['red', 'orange', 'yellow', 'green']

# %%
# append
rainbow.append('voilet')
rainbow
# Out:
# ['red', 'orange', 'yellow', 'green', 'voilet']

# %%
# insert
rainbow.insert(2, 'blue')
rainbow
# Out:
# ['red', 'orange', 'blue', 'yellow', 'green', 'voilet']

# %%
# pop
rainbow.pop()
rainbow
# Out:
# ['red', 'orange', 'blue', 'yellow', 'green']

# %%
# remove
from os import remove
rainbow.remove('orange')

# %%
# extend
rainbow.extend(['blue', 'voilet'])
rainbow
# Out:
# ['red', 'blue', 'yellow', 'green', 'blue', 'voilet']

# %%
rainbow.clear()
rainbow
# Out:
# []

# %% [markdown]
# ### List Method
#
#
#
# 1. sort() - Sorts the list in ascending order.
# If we want to print it in descending order then reverse = True.
#
# 2. reverse() - Reverse the order of list.
#
# 3. index() - Returns the index of list item.
#
# 4. count() - Counts the number of items in list.
#
# 5. copy() -Returns the copy of list.

# %%
tea_varities = ['White', 'Green', 'Lemon', 'Black', 'Black']

# %%
# sort
tea_varities.sort()
tea_varities
# Out:
# ['Black', 'Black', 'Green', 'Lemon', 'White']

# %%
# sort(reverse = True)
tea_varities.sort(reverse = True)
tea_varities
# Out:
# ['White', 'Lemon', 'Green', 'Black', 'Black']

# %%
# reverse
tea_varities.reverse()
tea_varities
# Out:
# ['Black', 'Black', 'Green', 'Lemon', 'White']

# %%
# index
tea_varities.index('Lemon')
# Out:
# 3

# %%
# count
tea_varities.count('Black')
# Out:
# 2

# %%
# copy
newlist = tea_varities.copy()
newlist
# Out:
# ['Black', 'Black', 'Green', 'Lemon', 'White']

# %% [markdown]
# ## Tuples
#
# A tuple is a collection of elements which are ordered. A tuple once defined cannot be modified.<br>
# Tuples with elements is created by elements separated by comma surrounding round brackets. Its actually Trailing commas that define a tuple not parentheses. Round brackets are required incase of ambiguity.<br>
# To iterate over the items of a tuple is faster compared to iterating over a list.

# %%
# tuple of strings
my_tuple = ("hello", "python", "hello", "world")
print(my_tuple)
# Out:
# ('hello', 'python', 'hello', 'world')

# %%
# tuple of int, float, string
my_tuple = (123, 2.228, "hello python")
print(my_tuple)
# Out:
# (123, 2.228, 'hello python')

# %%
# tuple of string and list
my_tuple = ("python", [12, 12, 31])
print(my_tuple)
# Out:
# ('python', [12, 12, 31])

# %%
# tuples inside another tuple
# nested tuple
my_tuple = ((2546, 332, 421), ("python", 63.1, "hi"))
print(my_tuple)
# Out:
# ((2546, 332, 421), ('python', 63.1, 'hi'))

# %% [markdown]
# **Access Tuple Elements**<br>
# Use indices to access the items of a tuple

# %%
# tuple of strings
my_tuple = ("mango", "yellow", "green", "blue")

# access the second element from the list
my_tuple[1]
# Out:
# 'yellow'

# %% [markdown]
# **Negative Indexing**<br>
# In Negative indexing position counting starts from the end, -1 refers to the last element, -2 refers to the second last element of the tuple

# %%
# print last item of the tuple
my_tuple[-1]
# Out:
# 'blue'

# %% [markdown]
# **Range of Indices**<br>
# Specify a range of indices by specifying the start and the end of the range. When specifying a range, the output will be a new tuple with the specified items

# %%
# define the tuple
my_tuple = ("mango", "yellow", "green", "blue", 353, 363.2, 'w')

# return fourth and fifth element from the list
my_tuple[3:5]
# Out:
# ('blue', 353)

# %%
# return the items from index -3 (included) to index -1 (excluded)
my_tuple[-3:-1]
# Out:
# (353, 363.2)

# %% [markdown]
# **Change Tuple Values**<br>
# We cannot change the items of a tuple because items of tuple are immutable. However we can change the elements of nested items in a tuple that are mutable

# %%
my_tuple = (123, ['s', 'a', 'v'], "World")
print(my_tuple)

# changing the element of the list
# this is valid because list is mutable
my_tuple[1][2] = 99
print(my_tuple)
# Out:
# (123, ['s', 'a', 'v'], 'World')
# (123, ['s', 'a', 99], 'World')

# %% [markdown]
# **Delete Operation on Tuple**<br>
# We already discussed above that we cannot delete the elements of a tuple. However deleting entire tuple is possible

# %%
# deleting entire tuple is possible
tuples = ("mango", "yellow", "green", "blue", 353, 363.2, 'w')
del tuples

# %% [markdown]
# **Tuple Methods**<br>
#
# Python has built-in methods which can be used on tuples:
# 1. count() - It returns the number of times a specified element occurs in a tuple
# 1. index() - It searches the tuple for the first occurance of a specified element and returns the index value for that particular position

# %%
my_tuple = ('a','p','p','l','e','e','d','e', 'd','e','a','c','w')
my_tuple.count('e')
# Out:
# 4

# %%
my_tuple = ('a','p','p','l','e','e','d','e', 'd','e','a','c','w')
my_tuple.index('l')
# Out:
# 3

# %% [markdown]
# # Sets
# It is a collection of unique items.<br>
# It is used to eliminate duplicate items from a list.<br>
# Also, it supports set operations like union intersection and difference.

# %% [markdown]
# **Creating Set**<br>
# In Python sets are written with curly brackets

# %%
# create a set
age_set = {11, 12, 31, 13, 24, 32, 33, 21, 23, 12}
print (age_set)

# create a set
set([1, 2, 3, 4])
# Out:
# {32, 33, 11, 12, 13, 21, 23, 24, 31}
# {1, 2, 3, 4}

# %% [markdown]
# Observed that the set contains unique items only even though we put duplicates into it.
#
# A set can contain elements of different data types.

# %%
# create a set
new_set = {12, 12, 'python', 4, 'world'}

# print
new_set
# Out:
# {12, 4, 'python', 'world'}

# %% [markdown]
# Following are the methods that you can use on sets:
# 1. add()
# 1. update()
# 1. len()
# 1. remove()
# 1. pop()
#
# **Change Items**<br>
# Once a set is created, you cannot modify its items, but you can add new items

# %% [markdown]
# **Add Items**<br>
# Use add() method to add one item to a set<br>
# Use update() method to add more than one item

# %%
# create a set
my_set = {'python','world'}

# add element
my_set.add("hi")

my_set
# Out:
# {'hi', 'python', 'world'}

# %% [markdown]
# Add multiple items to a set

# %%
# create a set
my_set = {'python','world'}

# update the set
my_set.update(['data science', 'machine learning'])

my_set
# Out:
# {'data science', 'machine learning', 'python', 'world'}

# %% [markdown]
# **Length of Set**

# %%
# print the length of set
len(my_set)
# Out:
# 4

# %% [markdown]
# **remove() method**<br>
# Use remove() or discard() method to remove an item in a set

# %%
# create a set
my_set = {'data science', 'machine learning', 'python', 'world'}

# remove element from list
my_set.remove('data science')

my_set
# Out:
# {'machine learning', 'python', 'world'}

# %% [markdown]
# **pop() method**<br>
# It removes a random element from the set and returns the removed element

# %%
# create a set
my_set = {'data science', 'machine learning', 'python', 'world'}

# remove random element from set
my_set.pop()
# Out:
# 'data science'

# %% [markdown]
# **Set Operations**
#
# **Disjoint set:**
# if the two sets have no common elements

# %%
print (set([11, 12, 22, 33, 4]).isdisjoint(set([4, 1])))
# Out:
# False

# %% [markdown]
# **Checking for subset**<br>
# Use issubset() method to check whether all elements of a set are contained in another set

# %%
# check whether one set 'a' is a subset of the 'b'
a = set([1, 3, 4, 5])
b = set([1, 3, 4, 5, 6])
print('Is a subset of b?', a.issubset(b))
# Out:
# Is a subset of b? True

# %% [markdown]
# **Set Union**<br>
# Use union() method to compute the union of two or more sets

# %%
a = set([1, 2, 3])
b = set([3, 4, 5, 6])
print (a.union(b))
# Out:
# {1, 2, 3, 4, 5, 6}

# %% [markdown]
# **Set Intersection**<br>
# Take intersection to find the common elements

# %%
a = set([12,34,56,78])
b = set([12,45,67,89,78])
c = set([12,34,56,78,56])
print (a & b)
print (a & b & c)
# Out:
# {12, 78}
# {12, 78}

# %% [markdown]
# **Set Difference**<br>
# It returns a new set containing all items from the first set that are not in the other set

# %%
a = set([23,45,56,77,89])
b = set([23,45,54,33,23])
print(a - b)
# Out:
# {56, 89, 77}

# %% [markdown]
# # Dictionary
#
# Python dictionary is an unordered collection of elements. It map keys to values and these key-value pairs provide a useful way to store data in python.
#
# **Syntax:**<br>
# dictionary_name = { key_1: value_1,key_2: value_2,key_3: value_3,}
#
# **Create Dictionary**<br>
# Separate keys from values with a colon(:), and a pair from another by a comma(,). Put it all in curly braces

# %%
# create dictionary
balance = {
    "Mia" : 83847,
    "John" : 83837,
    "Jill" : 94766
}
print(balance)
# Out:
# {'Mia': 83847, 'John': 83837, 'Jill': 94766}

# %% [markdown]
# **Accessing Items**<br>
# Use the key name inside the square brackets to access the elements from a dictionary

# %%
# Get the value for key "Mia"
x = balance["Mia"]
x
# Out:
# 83847

# %%
x = balance.get("Mia")
x
# Out:
# 83847

# %% [markdown]
# **Change Values**<br>
# Change the value of a specific element by referring to its key name

# %%
# create a dictionary
year_sales = {
  2015: 34500,
  2016: 34300,
  2017: 40000
}

# Change the sales figure for 2015
year_sales[2015] = 45000

year_sales
# Out:
# {2015: 45000, 2016: 34300, 2017: 40000}

# %%
# print the length of dictionary
print(len(year_sales))
# Out:
# 3

# %% [markdown]
# **Adding Items**<br>
# Add an item to the dictionary by using a new index key and assign a value to it

# %%
# create a dictionary
year_sales = {
  2015: 34500,
  2016: 34300,
  2017: 40000
}

year_sales['2018'] = 55000

year_sales
# Out:
# {2015: 34500, 2016: 34300, 2017: 40000, '2018': 55000}

# %% [markdown]
# ### Dictionary Method
#
# 1. keys() method
# 1. values() method
# 1. items() method
# 1. pop() method
# 1. popitem() method
# 1. del keywords
# 1. clear() method
# 1. copy() method
# 1. update() method
